# %%
# Univariat multi-variate
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pt

# %%
#df = pd.read_csv('https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv')
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
## univariate Anaysis

# %%
df_setosa = df.loc[df['species']=='setosa'] # only Setosa species
df_virginica = df.loc[df['species']=='virginica'] # only virginica 
df_versicolor = df.loc[df['species']=='versicolor']

# %%
plt.plot(df_setosa['sepal_length'], np.zeros_like(df_setosa['sepal_length']),'o')
plt.plot(df_virginica['sepal_length'], np.zeros_like(df_virginica['sepal_length']),'o')
plt.plot(df_versicolor['sepal_length'], np.zeros_like(df_versicolor['sepal_length']),'o')
plt.xlabel('Petal_ength')
# Out:
# /home/abay/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1377: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /home/abay/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:237: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# Text(0.5, 0, 'Petal_ength')

# %%
## Bivariat
sns.FacetGrid(df, hue='species', size=5).map(plt.scatter, 'sepal_length', 'sepal_width').add_legend()
plt.show()
# Out:
# /home/abay/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
## MuVti variate anaysis
sns.pairplot(df, hue='species', size=5)
# Out:
# /home/abay/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# /home/abay/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Dispay most frequent vaue 
num_series = pd.Series(np.random.randint(1,10,9))

# %%
#re = np.argwhere(num_series%5==0)

# %%
# Adding a column in a data frame
data = {'Col_1': pd.Series([0,1,3,4,5], index = ['a','b','c', 'd', 'e']), 
        'col_2': pd.Series([2,3,4,5,6], index=['a','b','c','d','e'])}
info = pd.DataFrame(data)
info['col_3'] = pd.Series([20,40,60], index=['a', 'b', 'c'])
info
# Out:
#    Col_1  col_2  col_3
# a      0      2   20.0
# b      1      3   40.0
# c      3      4   60.0
# d      4      5    NaN
# e      5      6    NaN

# %%
# Count the occurence of each value 
arr = np.array([2,4,5,3,2,5,6,3,3])
count = np.bincount(arr)
count
# Out:
# array([0, 0, 2, 3, 1, 2, 1])

# %%
# Concatination af arrays
x = np.random.rand(10,1)
y = np.random.rand(10,1)
conc = np.concatenate((x,y), axis=1)
conc
# Out:
# array([[0.65901766, 0.64452469],
#        [0.63854239, 0.08021386],
#        [0.55733066, 0.82093652],
#        [0.82136719, 0.48566694],
#        [0.92440171, 0.82059518],
#        [0.34838877, 0.46952517],
#        [0.55692593, 0.90457654],
#        [0.77356054, 0.74951136],
#        [0.91720636, 0.99310021],
#        [0.09165487, 0.95133036]])

# %%
# Removing the remove redundunt eements in two arrays 
x = np.array([1,3,4,5,6])
y = np.array([1,5,2,6,3])
x_new = np.setdiff1d(x,y)
x_new
# Out:
# array([4])

# %%
# Sort an  array by a specific column 
A = np.array([[2,3,4],[0,2,0],[3,1,4]])
SA = A[A[:,1].argsort()] #sorted based on the second comn

# %%
# Reverse an array 
x = np.array([1,2,3,4,5])
x_rev = x[::-1]
x_rev
# Out:
# array([5, 4, 3, 2, 1])

# %%
# Cacuate the percentile of an array 
x = np.array([2,3,4,1,5,6])
perce_of_x = np.percentile(x,40)
perce_of_x
# Out:
# 3.0

# %%
# check empty array
arr = np.zeros((10,0))
arr.size
# Out:
# array([], shape=(10, 0), dtype=float64)

# %%
#Compare two arrays 
x = np.random.rand(10,1)
y = np.random.rand(10,1)
i = x>y

# %%
# Calculate the dofference between the max and min value of a given array along the second axis 
A = np.arange(16).reshape((4,4))
res = np.ptp(A, 1)
res
# Out:
# array([3, 3, 3, 3])

# %%
# power element wise 
x = np.arange(4)
z = np.power(x,3)
y = np.true_divide(x,3)
y
# Out:
# array([0.        , 0.33333333, 0.66666667, 1.        ])

# %% [markdown]
# ## Abay
